# %% [markdown]
# # DS Automation Assignment

# %% [markdown]
# Using our prepared churn data from week 2:
# - use pycaret to find an ML algorithm that performs best on the data
#     - Choose a metric you think is best to use for finding the best model; by default, it is accuracy but it could be AUC, precision, recall, etc. The week 3 FTE has some information on these different metrics.
# - save the model to disk
# - create a Python script/file/module with a function that takes a pandas dataframe as an input and returns the probability of churn for each row in the dataframe
#     - your Python file/function should print out the predictions for new data (new_churn_data.csv)
#     - the true values for the new data are [1, 0, 0, 1, 0] if you're interested
# - test your Python module and function with the new data, new_churn_data.csv
# - write a short summary of the process and results at the end of this notebook
# - upload this Jupyter Notebook and Python file to a Github repository, and turn in a link to the repository in the week 5 assignment dropbox
#
# *Optional* challenges:
# - return the probability of churn for each new prediction, and the percentile where that prediction is in the distribution of probability predictions from the training dataset (e.g. a high probability of churn like 0.78 might be at the 90th percentile)
# - use other autoML packages, such as TPOT, H2O, MLBox, etc, and compare performance and features with pycaret
# - create a class in your Python module to hold the functions that you created
# - accept user input to specify a file using a tool such as Python's `input()` function, the `click` package for command-line arguments, or a GUI
# - Use the unmodified churn data (new_unmodified_churn_data.csv) in your Python script. This will require adding the same preprocessing steps from week 2 since this data is like the original unmodified dataset from week 1.

# %%
import pandas as pd

df = pd.read_csv('prepped_churn_data.csv', index_col='customerID')
df
# Out:
#             tenure  PhoneService  Contract  PaymentMethod  MonthlyCharges  \
# customerID
# 7590-VHVEG       1             1         0              2           29.85
# 5575-GNVDE      34             0         1              3           56.95
# 3668-QPYBK       2             0         0              3           53.85
# 7795-CFOCW      45             1         1              0           42.30
# 9237-HQITU       2             0         0              2           70.70
# ...            ...           ...       ...            ...             ...
# 6840-RESVB      24             0         1              3           84.80
# 2234-XADUH      72             0         1              1          103.20
# 4801-JZAZL      11             1         0              2           29.60
# 8361-LTMKD       4             0         0              3           74.40
# 3186-AJIEK      66             0         2              0          105.65
#
#             TotalCharges  Churn  AverageMonthlyCharges
# customerID
# 7590-VHVEG         29.85      1              29.850000
# 5575-GNVDE       1889.50      1              55.573529
# 3668-QPYBK        108.15      0              54.075000
# 7795-CFOCW       1840.75      1              40.905556
# 9237-HQITU        151.65      0              75.825000
# ...                  ...    ...                    ...
# 6840-RESVB       1990.50      1              82.937500
# 2234-XADUH       7362.90      1             102.262500
# 4801-JZAZL        346.45      1              31.495455
# 8361-LTMKD        306.60      0              76.650000
# 3186-AJIEK       6844.50      1             103.704545
#
# [7032 rows x 8 columns]

# %%
! conda install -c conda-forge pycaret -y
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# # All requested packages already installed.

# %%
from pycaret.classification import setup, compare_models, predict_model, save_model, load_model

# %%
# ?setup

# %%
automl = setup(df, target='Churn',fold_shuffle=True)
# Out:
# <style type="text/css">
# </style>
# <table id="T_7191b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7191b_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_7191b_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7191b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7191b_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_7191b_row0_col1" class="data row0 col1" >2500</td>
#     </tr>
#     <tr>
#       <th id="T_7191b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7191b_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_7191b_row1_col1" class="data row1 col1" >Churn</td>
#     </tr>
#     <tr>
#       <th id="T_7191b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7191b_row2_col0" class="data row2 col0" >Target Type</td>
#       <td id="T_7191b_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_7191b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7191b_row3_col0" class="data row3 col0" >Label Encoded</td>
#       <td id="T_7191b_row3_col1" class="data row3 col1" >0: 0, 1: 1</td>
#     </tr>
#     <tr>
#       <th id="T_7191b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7191b_row4_col0" class="data row4 col0" >Original Data</td>
#       <td id="T_7191b_row4_col1" class="data row4 col1" >(7032, 8)</td>
#     </tr>
#     <tr>
#       <th id="T_7191b_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_7191b_row5_col0" class="data row5 col0" >Missing Values</td>
#       <td id="T_7191b_row5_col1" class="data row5 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_7191b_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_7191b_row6_col0" class="data row6 col0" >Numeric Features</td>
#       <td id="T_7191b_row6_col1" class="data row6 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_7191b_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_7191b_row7_col0" class="data row7 col0" >Categorical Features</td>
#       <td id="T_7191b_row7_col1" class="data row7 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_7191b_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_7191b_row8_col0" class="data row8 col0" >Ordinal Features</td>
#       <td id="T_7191b_row8_col1" class="data row8 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_7191b_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_7191b_row9_col0" class="data row9 col0" >High Cardinality Features</td>
#       <td id="T_7191b_row9_col1" class="data row9 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_7191b_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_7191b_row10_col0" class="data row10 col0" >High Cardinality Method</td>
#       <td id="T_7191b_row10_col1" class="data row10 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_7191b_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_7191b_row11_col0" class="data row11 col0" >Transformed Train Set</td>
#       <td id="T_7191b_row11_col1" class="data row11 col1" >(4922, 11)</td>
#     </tr>
#     <tr>
#       <th id="T_7191b_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_7191b_row12_col0" class="data row12 col0" >Transformed Test Set</td>
#       <td id="T_7191b_row12_col1" class="data row12 col1" >(2110, 11)</td>
#     </tr>
#     <tr>
#       <th id="T_7191b_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_7191b_row13_col0" class="data row13 col0" >Shuffle Train-Test</td>
#       <td id="T_7191b_row13_col1" class="data row13 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_7191b_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_7191b_row14_col0" class="data row14 col0" >Stratify Train-Test</td>
#       <td id="T_7191b_row14_col1" class="data row14 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_7191b_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_7191b_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_7191b_row15_col1" class="data row15 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_7191b_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_7191b_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_7191b_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_7191b_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_7191b_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_7191b_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_7191b_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_7191b_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_7191b_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_7191b_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_7191b_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_7191b_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_7191b_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_7191b_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_7191b_row20_col1" class="data row20 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_7191b_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_7191b_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_7191b_row21_col1" class="data row21 col1" >2428</td>
#     </tr>
#     <tr>
#       <th id="T_7191b_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_7191b_row22_col0" class="data row22 col0" >Imputation Type</td>
#       <td id="T_7191b_row22_col1" class="data row22 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_7191b_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_7191b_row23_col0" class="data row23 col0" >Iterative Imputation Iteration</td>
#       <td id="T_7191b_row23_col1" class="data row23 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_7191b_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_7191b_row24_col0" class="data row24 col0" >Numeric Imputer</td>
#       <td id="T_7191b_row24_col1" class="data row24 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_7191b_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_7191b_row25_col0" class="data row25 col0" >Iterative Imputation Numeric Model</td>
#       <td id="T_7191b_row25_col1" class="data row25 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_7191b_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_7191b_row26_col0" class="data row26 col0" >Categorical Imputer</td>
#       <td id="T_7191b_row26_col1" class="data row26 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_7191b_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_7191b_row27_col0" class="data row27 col0" >Iterative Imputation Categorical Model</td>
#       <td id="T_7191b_row27_col1" class="data row27 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_7191b_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_7191b_row28_col0" class="data row28 col0" >Unknown Categoricals Handling</td>
#       <td id="T_7191b_row28_col1" class="data row28 col1" >least_frequent</td>
#     </tr>
#     <tr>
#       <th id="T_7191b_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_7191b_row29_col0" class="data row29 col0" >Normalize</td>
#       <td id="T_7191b_row29_col1" class="data row29 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_7191b_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_7191b_row30_col0" class="data row30 col0" >Normalize Method</td>
#       <td id="T_7191b_row30_col1" class="data row30 col1" >None</td>
#     </tr>
#     <tr>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [102], in <cell line: 1>()
# ----> 1 automl = setup(df, target='Churn',fold_shuffle=True)
#
# File C:\Users\NickMolliconi\lib\site-packages\pycaret\classification.py:580, in setup(data, target, train_size, test_data, preprocess, imputation_type, iterative_imputation_iters, categorical_features, categorical_imputation, categorical_iterative_imputer, ordinal_features, high_cardinality_features, high_cardinality_method, numeric_features, numeric_imputation, numeric_iterative_imputer, date_features, ignore_features, normalize, normalize_method, transformation, transformation_method, handle_unknown_categorical, unknown_categorical_method, pca, pca_method, pca_components, ignore_low_variance, combine_rare_levels, rare_level_threshold, bin_numeric_features, remove_outliers, outliers_threshold, remove_multicollinearity, multicollinearity_threshold, remove_perfect_collinearity, create_clusters, cluster_iter, polynomial_features, polynomial_degree, trigonometry_features, polynomial_threshold, group_features, group_names, feature_selection, feature_selection_threshold, feature_selection_method, feature_interaction, feature_ratio, interaction_threshold, fix_imbalance, fix_imbalance_method, data_split_shuffle, data_split_stratify, fold_strategy, fold, fold_shuffle, fold_groups, n_jobs, use_gpu, custom_pipeline, html, session_id, log_experiment, experiment_name, log_plots, log_profile, log_data, silent, verbose, profile, profile_kwargs)
#     577 if log_plots == True:
#     578     log_plots = ["auc", "confusion_matrix", "feature"]
# --> 580 return pycaret.internal.tabular.setup(
#     581     ml_usecase="classification",
#     582     available_plots=available_plots,
#     583     data=data,
#     584     target=target,
#     585     train_size=train_size,
#     586     test_data=test_data,
#     587     preprocess=preprocess,
#     588     imputation_type=imputation_type,
#     589     iterative_imputation_iters=iterative_imputation_iters,
#     590     categorical_features=categorical_features,
#     591     categorical_imputation=categorical_imputation,
#     592     categorical_iterative_imputer=categorical_iterative_imputer,
#     593     ordinal_features=ordinal_features,
#     594     high_cardinality_features=high_cardinality_features,
#     595     high_cardinality_method=high_cardinality_method,
#     596     numeric_features=numeric_features,
#     597     numeric_imputation=numeric_imputation,
#     598     numeric_iterative_imputer=numeric_iterative_imputer,
#     599     date_features=date_features,
#     600     ignore_features=ignore_features,
#     601     normalize=normalize,
#     602     normalize_method=normalize_method,
#     603     transformation=transformation,
#     604     transformation_method=transformation_method,
#     605     handle_unknown_categorical=handle_unknown_categorical,
#     606     unknown_categorical_method=unknown_categorical_method,
#     607     pca=pca,
#     608     pca_method=pca_method,
#     609     pca_components=pca_components,
#     610     ignore_low_variance=ignore_low_variance,
#     611     combine_rare_levels=combine_rare_levels,
#     612     rare_level_threshold=rare_level_threshold,
#     613     bin_numeric_features=bin_numeric_features,
#     614     remove_outliers=remove_outliers,
#     615     outliers_threshold=outliers_threshold,
#     616     remove_multicollinearity=remove_multicollinearity,
#     617     multicollinearity_threshold=multicollinearity_threshold,
#     618     remove_perfect_collinearity=remove_perfect_collinearity,
#     619     create_clusters=create_clusters,
#     620     cluster_iter=cluster_iter,
#     621     polynomial_features=polynomial_features,
#     622     polynomial_degree=polynomial_degree,
#     623     trigonometry_features=trigonometry_features,
#     624     polynomial_threshold=polynomial_threshold,
#     625     group_features=group_features,
#     626     group_names=group_names,
#     627     feature_selection=feature_selection,
#     628     feature_selection_threshold=feature_selection_threshold,
#     629     feature_selection_method=feature_selection_method,
#     630     feature_interaction=feature_interaction,
#     631     feature_ratio=feature_ratio,
#     632     interaction_threshold=interaction_threshold,
#     633     fix_imbalance=fix_imbalance,
#     634     fix_imbalance_method=fix_imbalance_method,
#     635     data_split_shuffle=data_split_shuffle,
#     636     data_split_stratify=data_split_stratify,
#     637     fold_strategy=fold_strategy,
#     638     fold=fold,
#     639     fold_shuffle=fold_shuffle,
#     640     fold_groups=fold_groups,
#     641     n_jobs=n_jobs,
#     642     use_gpu=use_gpu,
#     643     custom_pipeline=custom_pipeline,
#     644     html=html,
#     645     session_id=session_id,
#     646     log_experiment=log_experiment,
#     647     experiment_name=experiment_name,
#     648     log_plots=log_plots,
#     649     log_profile=log_profile,
#     650     log_data=log_data,
#     651     silent=silent,
#     652     verbose=verbose,
#     653     profile=profile,
#     654     profile_kwargs=profile_kwargs,
#     655 )
#
# File C:\Users\NickMolliconi\lib\site-packages\pycaret\internal\tabular.py:1750, in setup(data, target, ml_usecase, available_plots, train_size, test_data, preprocess, imputation_type, iterative_imputation_iters, categorical_features, categorical_imputation, categorical_iterative_imputer, ordinal_features, high_cardinality_features, high_cardinality_method, numeric_features, numeric_imputation, numeric_iterative_imputer, date_features, ignore_features, normalize, normalize_method, transformation, transformation_method, handle_unknown_categorical, unknown_categorical_method, pca, pca_method, pca_components, ignore_low_variance, combine_rare_levels, rare_level_threshold, bin_numeric_features, remove_outliers, outliers_threshold, remove_multicollinearity, multicollinearity_threshold, remove_perfect_collinearity, create_clusters, cluster_iter, polynomial_features, polynomial_degree, trigonometry_features, polynomial_threshold, group_features, group_names, feature_selection, feature_selection_threshold, feature_selection_method, feature_interaction, feature_ratio, interaction_threshold, fix_imbalance, fix_imbalance_method, transform_target, transform_target_method, data_split_shuffle, data_split_stratify, fold_strategy, fold, fold_shuffle, fold_groups, n_jobs, use_gpu, custom_pipeline, html, session_id, log_experiment, experiment_name, log_plots, log_profile, log_data, silent, verbose, profile, profile_kwargs, display)
#    1747 logger.info(f"master_model_container: {len(master_model_container)}")
#    1748 logger.info(f"display_container: {len(display_container)}")
# -> 1750 logger.info(str(prep_pipe))
#    1751 logger.info("setup() succesfully completed......................................")
#    1753 gc.collect()
#
# File C:\Users\NickMolliconi\lib\site-packages\sklearn\base.py:279, in BaseEstimator.__repr__(self, N_CHAR_MAX)
#     271 # use ellipsis for sequences with a lot of elements
#     272 pp = _EstimatorPrettyPrinter(
#     273     compact=True,
#     274     indent=1,
#     275     indent_at_name=True,
#     276     n_max_elements_to_show=N_MAX_ELEMENTS_TO_SHOW,
#     277 )
# --> 279 repr_ = pp.pformat(self)
#     281 # Use bruteforce ellipsis when there are a lot of non-blank characters
#     282 n_nonblank = len("".join(repr_.split()))
#
# File C:\Users\NickMolliconi\lib\pprint.py:153, in PrettyPrinter.pformat(self, object)
#     151 def pformat(self, object):
#     152     sio = _StringIO()
# --> 153     self._format(object, sio, 0, 0, {}, 0)
#     154     return sio.getvalue()
#
# File C:\Users\NickMolliconi\lib\pprint.py:170, in PrettyPrinter._format(self, object, stream, indent, allowance, context, level)
#     168     self._readable = False
#     169     return
# --> 170 rep = self._repr(object, context, level)
#     171 max_width = self._width - indent - allowance
#     172 if len(rep) > max_width:
#
# File C:\Users\NickMolliconi\lib\pprint.py:431, in PrettyPrinter._repr(self, object, context, level)
#     430 def _repr(self, object, context, level):
# --> 431     repr, readable, recursive = self.format(object, context.copy(),
#     432                                             self._depth, level)
#     433     if not readable:
#     434         self._readable = False
#
# File C:\Users\NickMolliconi\lib\site-packages\sklearn\utils\_pprint.py:189, in _EstimatorPrettyPrinter.format(self, object, context, maxlevels, level)
#     188 def format(self, object, context, maxlevels, level):
# --> 189     return _safe_repr(
#     190         object, context, maxlevels, level, changed_only=self._changed_only
#     191     )
#
# File C:\Users\NickMolliconi\lib\site-packages\sklearn\utils\_pprint.py:452, in _safe_repr(object, context, maxlevels, level, changed_only)
#     448 for k, v in items:
#     449     krepr, kreadable, krecur = saferepr(
#     450         k, context, maxlevels, level, changed_only=changed_only
#     451     )
# --> 452     vrepr, vreadable, vrecur = saferepr(
#     453         v, context, maxlevels, level, changed_only=changed_only
#     454     )
#     455     append("%s=%s" % (krepr.strip("'"), vrepr))
#     456     readable = readable and kreadable and vreadable
#
# File C:\Users\NickMolliconi\lib\site-packages\sklearn\utils\_pprint.py:419, in _safe_repr(object, context, maxlevels, level, changed_only)
#     417 level += 1
#     418 for o in object:
# --> 419     orepr, oreadable, orecur = _safe_repr(
#     420         o, context, maxlevels, level, changed_only=changed_only
#     421     )
#     422     append(orepr)
#     423     if not oreadable:
#
# File C:\Users\NickMolliconi\lib\site-packages\sklearn\utils\_pprint.py:419, in _safe_repr(object, context, maxlevels, level, changed_only)
#     417 level += 1
#     418 for o in object:
# --> 419     orepr, oreadable, orecur = _safe_repr(
#     420         o, context, maxlevels, level, changed_only=changed_only
#     421     )
#     422     append(orepr)
#     423     if not oreadable:
#
# File C:\Users\NickMolliconi\lib\site-packages\sklearn\utils\_pprint.py:442, in _safe_repr(object, context, maxlevels, level, changed_only)
#     440     params = _changed_params(object)
#     441 else:
# --> 442     params = object.get_params(deep=False)
#     443 components = []
#     444 append = components.append
#
# File C:\Users\NickMolliconi\lib\site-packages\sklearn\base.py:211, in BaseEstimator.get_params(self, deep)
#     209 out = dict()
#     210 for key in self._get_param_names():
# --> 211     value = getattr(self, key)
#     212     if deep and hasattr(value, "get_params"):
#     213         deep_items = value.get_params().items()
#
# AttributeError: 'Simple_Imputer' object has no attribute 'fill_value_categorical'

# %%
best_model = compare_models()
# Out:
# <style type="text/css">
# #T_f7cd7 th {
#   text-align: left;
# }
# #T_f7cd7_row0_col0, #T_f7cd7_row0_col3, #T_f7cd7_row0_col4, #T_f7cd7_row0_col5, #T_f7cd7_row0_col6, #T_f7cd7_row0_col7, #T_f7cd7_row1_col0, #T_f7cd7_row1_col1, #T_f7cd7_row1_col2, #T_f7cd7_row1_col3, #T_f7cd7_row1_col4, #T_f7cd7_row1_col6, #T_f7cd7_row1_col7, #T_f7cd7_row2_col0, #T_f7cd7_row2_col1, #T_f7cd7_row2_col2, #T_f7cd7_row2_col3, #T_f7cd7_row2_col4, #T_f7cd7_row2_col5, #T_f7cd7_row3_col0, #T_f7cd7_row3_col1, #T_f7cd7_row3_col2, #T_f7cd7_row3_col3, #T_f7cd7_row3_col4, #T_f7cd7_row3_col5, #T_f7cd7_row3_col7, #T_f7cd7_row4_col0, #T_f7cd7_row4_col1, #T_f7cd7_row4_col2, #T_f7cd7_row4_col4, #T_f7cd7_row4_col5, #T_f7cd7_row4_col6, #T_f7cd7_row4_col7, #T_f7cd7_row5_col0, #T_f7cd7_row5_col1, #T_f7cd7_row5_col2, #T_f7cd7_row5_col3, #T_f7cd7_row5_col4, #T_f7cd7_row5_col5, #T_f7cd7_row5_col6, #T_f7cd7_row5_col7, #T_f7cd7_row6_col0, #T_f7cd7_row6_col1, #T_f7cd7_row6_col2, #T_f7cd7_row6_col3, #T_f7cd7_row6_col4, #T_f7cd7_row6_col5, #T_f7cd7_row6_col6, #T_f7cd7_row6_col7, #T_f7cd7_row7_col0, #T_f7cd7_row7_col1, #T_f7cd7_row7_col2, #T_f7cd7_row7_col3, #T_f7cd7_row7_col4, #T_f7cd7_row7_col5, #T_f7cd7_row7_col6, #T_f7cd7_row7_col7, #T_f7cd7_row8_col0, #T_f7cd7_row8_col1, #T_f7cd7_row8_col2, #T_f7cd7_row8_col3, #T_f7cd7_row8_col4, #T_f7cd7_row8_col5, #T_f7cd7_row8_col6, #T_f7cd7_row8_col7, #T_f7cd7_row9_col0, #T_f7cd7_row9_col1, #T_f7cd7_row9_col2, #T_f7cd7_row9_col3, #T_f7cd7_row9_col4, #T_f7cd7_row9_col5, #T_f7cd7_row9_col6, #T_f7cd7_row9_col7, #T_f7cd7_row10_col0, #T_f7cd7_row10_col1, #T_f7cd7_row10_col2, #T_f7cd7_row10_col3, #T_f7cd7_row10_col4, #T_f7cd7_row10_col5, #T_f7cd7_row10_col6, #T_f7cd7_row10_col7, #T_f7cd7_row11_col0, #T_f7cd7_row11_col1, #T_f7cd7_row11_col2, #T_f7cd7_row11_col3, #T_f7cd7_row11_col4, #T_f7cd7_row11_col5, #T_f7cd7_row11_col6, #T_f7cd7_row11_col7, #T_f7cd7_row12_col0, #T_f7cd7_row12_col1, #T_f7cd7_row12_col2, #T_f7cd7_row12_col3, #T_f7cd7_row12_col5, #T_f7cd7_row12_col6, #T_f7cd7_row12_col7, #T_f7cd7_row13_col0, #T_f7cd7_row13_col1, #T_f7cd7_row13_col2, #T_f7cd7_row13_col3, #T_f7cd7_row13_col4, #T_f7cd7_row13_col5, #T_f7cd7_row13_col6, #T_f7cd7_row13_col7, #T_f7cd7_row14_col0, #T_f7cd7_row14_col1, #T_f7cd7_row14_col2, #T_f7cd7_row14_col3, #T_f7cd7_row14_col4, #T_f7cd7_row14_col5, #T_f7cd7_row14_col6, #T_f7cd7_row14_col7 {
#   text-align: left;
# }
# #T_f7cd7_row0_col1, #T_f7cd7_row0_col2, #T_f7cd7_row1_col5, #T_f7cd7_row2_col6, #T_f7cd7_row2_col7, #T_f7cd7_row3_col6, #T_f7cd7_row4_col3, #T_f7cd7_row12_col4 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_f7cd7_row0_col8, #T_f7cd7_row1_col8, #T_f7cd7_row2_col8, #T_f7cd7_row3_col8, #T_f7cd7_row4_col8, #T_f7cd7_row5_col8, #T_f7cd7_row6_col8, #T_f7cd7_row7_col8, #T_f7cd7_row8_col8, #T_f7cd7_row9_col8, #T_f7cd7_row10_col8, #T_f7cd7_row11_col8, #T_f7cd7_row12_col8, #T_f7cd7_row13_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_f7cd7_row14_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_f7cd7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f7cd7_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_f7cd7_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_f7cd7_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_f7cd7_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_f7cd7_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_f7cd7_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_f7cd7_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_f7cd7_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_f7cd7_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f7cd7_level0_row0" class="row_heading level0 row0" >ada</th>
#       <td id="T_f7cd7_row0_col0" class="data row0 col0" >Ada Boost Classifier</td>
#       <td id="T_f7cd7_row0_col1" class="data row0 col1" >0.7871</td>
#       <td id="T_f7cd7_row0_col2" class="data row0 col2" >0.8348</td>
#       <td id="T_f7cd7_row0_col3" class="data row0 col3" >0.8981</td>
#       <td id="T_f7cd7_row0_col4" class="data row0 col4" >0.8263</td>
#       <td id="T_f7cd7_row0_col5" class="data row0 col5" >0.8606</td>
#       <td id="T_f7cd7_row0_col6" class="data row0 col6" >0.4129</td>
#       <td id="T_f7cd7_row0_col7" class="data row0 col7" >0.4205</td>
#       <td id="T_f7cd7_row0_col8" class="data row0 col8" >0.0610</td>
#     </tr>
#     <tr>
#       <th id="T_f7cd7_level0_row1" class="row_heading level0 row1" >gbc</th>
#       <td id="T_f7cd7_row1_col0" class="data row1 col0" >Gradient Boosting Classifier</td>
#       <td id="T_f7cd7_row1_col1" class="data row1 col1" >0.7869</td>
#       <td id="T_f7cd7_row1_col2" class="data row1 col2" >0.8345</td>
#       <td id="T_f7cd7_row1_col3" class="data row1 col3" >0.9012</td>
#       <td id="T_f7cd7_row1_col4" class="data row1 col4" >0.8242</td>
#       <td id="T_f7cd7_row1_col5" class="data row1 col5" >0.8608</td>
#       <td id="T_f7cd7_row1_col6" class="data row1 col6" >0.4092</td>
#       <td id="T_f7cd7_row1_col7" class="data row1 col7" >0.4178</td>
#       <td id="T_f7cd7_row1_col8" class="data row1 col8" >0.1320</td>
#     </tr>
#     <tr>
#       <th id="T_f7cd7_level0_row2" class="row_heading level0 row2" >lightgbm</th>
#       <td id="T_f7cd7_row2_col0" class="data row2 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_f7cd7_row2_col1" class="data row2 col1" >0.7855</td>
#       <td id="T_f7cd7_row2_col2" class="data row2 col2" >0.8233</td>
#       <td id="T_f7cd7_row2_col3" class="data row2 col3" >0.8864</td>
#       <td id="T_f7cd7_row2_col4" class="data row2 col4" >0.8316</td>
#       <td id="T_f7cd7_row2_col5" class="data row2 col5" >0.8580</td>
#       <td id="T_f7cd7_row2_col6" class="data row2 col6" >0.4204</td>
#       <td id="T_f7cd7_row2_col7" class="data row2 col7" >0.4249</td>
#       <td id="T_f7cd7_row2_col8" class="data row2 col8" >0.2270</td>
#     </tr>
#     <tr>
#       <th id="T_f7cd7_level0_row3" class="row_heading level0 row3" >lr</th>
#       <td id="T_f7cd7_row3_col0" class="data row3 col0" >Logistic Regression</td>
#       <td id="T_f7cd7_row3_col1" class="data row3 col1" >0.7850</td>
#       <td id="T_f7cd7_row3_col2" class="data row3 col2" >0.8278</td>
#       <td id="T_f7cd7_row3_col3" class="data row3 col3" >0.8851</td>
#       <td id="T_f7cd7_row3_col4" class="data row3 col4" >0.8321</td>
#       <td id="T_f7cd7_row3_col5" class="data row3 col5" >0.8576</td>
#       <td id="T_f7cd7_row3_col6" class="data row3 col6" >0.4204</td>
#       <td id="T_f7cd7_row3_col7" class="data row3 col7" >0.4245</td>
#       <td id="T_f7cd7_row3_col8" class="data row3 col8" >0.7850</td>
#     </tr>
#     <tr>
#       <th id="T_f7cd7_level0_row4" class="row_heading level0 row4" >ridge</th>
#       <td id="T_f7cd7_row4_col0" class="data row4 col0" >Ridge Classifier</td>
#       <td id="T_f7cd7_row4_col1" class="data row4 col1" >0.7836</td>
#       <td id="T_f7cd7_row4_col2" class="data row4 col2" >0.0000</td>
#       <td id="T_f7cd7_row4_col3" class="data row4 col3" >0.9084</td>
#       <td id="T_f7cd7_row4_col4" class="data row4 col4" >0.8167</td>
#       <td id="T_f7cd7_row4_col5" class="data row4 col5" >0.8600</td>
#       <td id="T_f7cd7_row4_col6" class="data row4 col6" >0.3893</td>
#       <td id="T_f7cd7_row4_col7" class="data row4 col7" >0.4012</td>
#       <td id="T_f7cd7_row4_col8" class="data row4 col8" >0.0110</td>
#     </tr>
#     <tr>
#       <th id="T_f7cd7_level0_row5" class="row_heading level0 row5" >lda</th>
#       <td id="T_f7cd7_row5_col0" class="data row5 col0" >Linear Discriminant Analysis</td>
#       <td id="T_f7cd7_row5_col1" class="data row5 col1" >0.7834</td>
#       <td id="T_f7cd7_row5_col2" class="data row5 col2" >0.8194</td>
#       <td id="T_f7cd7_row5_col3" class="data row5 col3" >0.8853</td>
#       <td id="T_f7cd7_row5_col4" class="data row5 col4" >0.8302</td>
#       <td id="T_f7cd7_

# %%
best_model
# Out:
# AdaBoostClassifier(algorithm='SAMME.R', base_estimator=None, learning_rate=1.0,
#                    n_estimators=50, random_state=2500)

# %%
df.iloc[-2:-1].shape
# Out:
# (1, 8)

# %%
predict_model(best_model, df.iloc[-2:-1])
# Out:
#             tenure  PhoneService  Contract  PaymentMethod  MonthlyCharges  \
# customerID
# 8361-LTMKD       4             0         0              3            74.4
#
#             TotalCharges  Churn  AverageMonthlyCharges  Label   Score
# customerID
# 8361-LTMKD         306.6      0                  76.65      0  0.5006

# %%
save_model(best_model, 'ada')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [108], in <cell line: 1>()
# ----> 1 save_model(best_model, 'ada')
#
# File C:\Users\NickMolliconi\lib\site-packages\pycaret\classification.py:2092, in save_model(model, model_name, model_only, verbose)
#    2054 def save_model(model, model_name: str, model_only: bool = False, verbose: bool = True):
#    2056     """
#    2057     This function saves the transformation pipeline and trained model object
#    2058     into the current working directory as a pickle file for later use.
#    (...)
#    2089
#    2090     """
# -> 2092     return pycaret.internal.tabular.save_model(
#    2093         model=model, model_name=model_name, model_only=model_only, verbose=verbose
#    2094     )
#
# File C:\Users\NickMolliconi\lib\site-packages\pycaret\internal\tabular.py:8909, in save_model(model, model_name, model_only, verbose)
#    8870 """
#    8871 This function saves the transformation pipeline and trained model object
#    8872 into the current active directory as a pickle file for later use.
#    (...)
#    8904
#    8905 """
#    8907 import pycaret.internal.persistence
# -> 8909 return pycaret.internal.persistence.save_model(
#    8910     model, model_name, None if model_only else prep_pipe, verbose
#    8911 )
#
# File C:\Users\NickMolliconi\lib\site-packages\pycaret\internal\persistence.py:263, in save_model(model, model_name, prep_pipe_, verbose)
#     236 def save_model(model, model_name: str, prep_pipe_=None, verbose: bool = True):
#     238     """
#     239     This generic function saves the transformation pipeline and trained model object
#     240     into the current active directory as a pickle file for later use.
#    (...)
#     260
#     261     """
# --> 263     function_params_str = ", ".join([f"{k}={v}" for k, v in locals().items()])
#     265     logger = get_logger()
#     267     logger.info("Initializing save_model()")
#
# File C:\Users\NickMolliconi\lib\site-packages\pycaret\internal\persistence.py:263, in <listcomp>(.0)
#     236 def save_model(model, model_name: str, prep_pipe_=None, verbose: bool = True):
#     238     """
#     239     This generic function saves the transformation pipeline and trained model object
#     240     into the current active directory as a pickle file for later use.
#    (...)
#     260
#     261     """
# --> 263     function_params_str = ", ".join([f"{k}={v}" for k, v in locals().items()])
#     265     logger = get_logger()
#     267     logger.info("Initializing save_model()")
#
# File C:\Users\NickMolliconi\lib\site-packages\sklearn\base.py:279, in BaseEstimator.__repr__(self, N_CHAR_MAX)
#     271 # use ellipsis for sequences with a lot of elements
#     272 pp = _EstimatorPrettyPrinter(
#     273     compact=True,
#     274     indent=1,
#     275     indent_at_name=True,
#     276     n_max_elements_to_show=N_MAX_ELEMENTS_TO_SHOW,
#     277 )
# --> 279 repr_ = pp.pformat(self)
#     281 # Use bruteforce ellipsis when there are a lot of non-blank characters
#     282 n_nonblank = len("".join(repr_.split()))
#
# File C:\Users\NickMolliconi\lib\pprint.py:153, in PrettyPrinter.pformat(self, object)
#     151 def pformat(self, object):
#     152     sio = _StringIO()
# --> 153     self._format(object, sio, 0, 0, {}, 0)
#     154     return sio.getvalue()
#
# File C:\Users\NickMolliconi\lib\pprint.py:170, in PrettyPrinter._format(self, object, stream, indent, allowance, context, level)
#     168     self._readable = False
#     169     return
# --> 170 rep = self._repr(object, context, level)
#     171 max_width = self._width - indent - allowance
#     172 if len(rep) > max_width:
#
# File C:\Users\NickMolliconi\lib\pprint.py:431, in PrettyPrinter._repr(self, object, context, level)
#     430 def _repr(self, object, context, level):
# --> 431     repr, readable, recursive = self.format(object, context.copy(),
#     432                                             self._depth, level)
#     433     if not readable:
#     434         self._readable = False
#
# File C:\Users\NickMolliconi\lib\site-packages\sklearn\utils\_pprint.py:189, in _EstimatorPrettyPrinter.format(self, object, context, maxlevels, level)
#     188 def format(self, object, context, maxlevels, level):
# --> 189     return _safe_repr(
#     190         object, context, maxlevels, level, changed_only=self._changed_only
#     191     )
#
# File C:\Users\NickMolliconi\lib\site-packages\sklearn\utils\_pprint.py:452, in _safe_repr(object, context, maxlevels, level, changed_only)
#     448 for k, v in items:
#     449     krepr, kreadable, krecur = saferepr(
#     450         k, context, maxlevels, level, changed_only=changed_only
#     451     )
# --> 452     vrepr, vreadable, vrecur = saferepr(
#     453         v, context, maxlevels, level, changed_only=changed_only
#     454     )
#     455     append("%s=%s" % (krepr.strip("'"), vrepr))
#     456     readable = readable and kreadable and vreadable
#
# File C:\Users\NickMolliconi\lib\site-packages\sklearn\utils\_pprint.py:419, in _safe_repr(object, context, maxlevels, level, changed_only)
#     417 level += 1
#     418 for o in object:
# --> 419     orepr, oreadable, orecur = _safe_repr(
#     420         o, context, maxlevels, level, changed_only=changed_only
#     421     )
#     422     append(orepr)
#     423     if not oreadable:
#
# File C:\Users\NickMolliconi\lib\site-packages\sklearn\utils\_pprint.py:419, in _safe_repr(object, context, maxlevels, level, changed_only)
#     417 level += 1
#     418 for o in object:
# --> 419     orepr, oreadable, orecur = _safe_repr(
#     420         o, context, maxlevels, level, changed_only=changed_only
#     421     )
#     422     append(orepr)
#     423     if not oreadable:
#
# File C:\Users\NickMolliconi\lib\site-packages\sklearn\utils\_pprint.py:442, in _safe_repr(object, context, maxlevels, level, changed_only)
#     440     params = _changed_params(object)
#     441 else:
# --> 442     params = object.get_params(deep=False)
#     443 components = []
#     444 append = components.append
#
# File C:\Users\NickMolliconi\lib\site-packages\sklearn\base.py:211, in BaseEstimator.get_params(self, deep)
#     209 out = dict()
#     210 for key in self._get_param_names():
# --> 211     value = getattr(self, key)
#     212     if deep and hasattr(value, "get_params"):
#     213         deep_items = value.get_params().items()
#
# AttributeError: 'Simple_Imputer' object has no attribute 'fill_value_categorical'

# %%
import pickle

with open('ada_model.pk', 'wb') as f:
    pickle.dump(best_model, f)

# %%
with open('ada_model.pk', 'rb') as f:
    loaded_model = pickle.load(f)

# %%
new_data = df.iloc[-2:-1].copy()
new_data.drop('Churn', axis=1, inplace=True)
loaded_model.predict(new_data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [112], in <cell line: 3>()
#       1 new_data = df.iloc[-2:-1].copy()
#       2 new_data.drop('Churn', axis=1, inplace=True)
# ----> 3 loaded_model.predict(new_data)
#
# File C:\Users\NickMolliconi\lib\site-packages\sklearn\ensemble\_weight_boosting.py:699, in AdaBoostClassifier.predict(self, X)
#     682 def predict(self, X):
#     683     """Predict classes for X.
#     684
#     685     The predicted class of an input sample is computed as the weighted mean
#    (...)
#     697         The predicted classes.
#     698     """
# --> 699     pred = self.decision_function(X)
#     701     if self.n_classes_ == 2:
#     702         return self.classes_.take(pred > 0, axis=0)
#
# File C:\Users\NickMolliconi\lib\site-packages\sklearn\ensemble\_weight_boosting.py:760, in AdaBoostClassifier.decision_function(self, X)
#     741 """Compute the decision function of ``X``.
#     742
#     743 Parameters
#    (...)
#     757     class in ``classes_``, respectively.
#     758 """
#     759 check_is_fitted(self)
# --> 760 X = self._check_X(X)
#     762 n_classes = self.n_classes_
#     763 classes = self.classes_[:, np.newaxis]
#
# File C:\Users\NickMolliconi\lib\site-packages\sklearn\ensemble\_weight_boosting.py:84, in BaseWeightBoosting._check_X(self, X)
#      82 def _check_X(self, X):
#      83     # Only called to validate X in non-fit methods, therefore reset=False
# ---> 84     return self._validate_data(
#      85         X,
#      86         accept_sparse=["csr", "csc"],
#      87         ensure_2d=True,
#      88         allow_nd=True,
#      89         dtype=None,
#      90         reset=False,
#      91     )
#
# File C:\Users\NickMolliconi\lib\site-packages\sklearn\base.py:600, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     597     out = X, y
#     599 if not no_val_X and check_params.get("ensure_2d", True):
# --> 600     self._check_n_features(X, reset=reset)
#     602 return out
#
# File C:\Users\NickMolliconi\lib\site-packages\sklearn\base.py:400, in BaseEstimator._check_n_features(self, X, reset)
#     397     return
#     399 if n_features != self.n_features_in_:
# --> 400     raise ValueError(
#     401         f"X has {n_features} features, but {self.__class__.__name__} "
#     402         f"is expecting {self.n_features_in_} features as input."
#     403     )
#
# ValueError: X has 7 features, but AdaBoostClassifier is expecting 11 features as input.

# %%
loaded_lda = load_model('ada')
# Out:
# Transformation Pipeline and Model Successfully Loaded
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [113], in <cell line: 1>()
# ----> 1 loaded_lda = load_model('ada')
#
# File C:\Users\NickMolliconi\lib\site-packages\pycaret\classification.py:2145, in load_model(model_name, platform, authentication, verbose)
#    2097 def load_model(
#    2098     model_name,
#    2099     platform: Optional[str] = None,
#    2100     authentication: Optional[Dict[str, str]] = None,
#    2101     verbose: bool = True,
#    2102 ):
#    2104     """
#    2105     This function loads a previously saved pipeline.
#    2106
#    (...)
#    2142
#    2143     """
# -> 2145     return pycaret.internal.tabular.load_model(
#    2146         model_name=model_name,
#    2147         platform=platform,
#    2148         authentication=authentication,
#    2149         verbose=verbose,
#    2150     )
#
# File C:\Users\NickMolliconi\lib\site-packages\pycaret\internal\tabular.py:8965, in load_model(model_name, platform, authentication, verbose)
#    8921 """
#    8922 This function loads a previously saved transformation pipeline and model
#    8923 from the current active directory into the current python environment.
#    (...)
#    8960
#    8961 """
#    8963 import pycaret.internal.persistence
# -> 8965 return pycaret.internal.persistence.load_model(
#    8966     model_name, platform, authentication, verbose
#    8967 )
#
# File C:\Users\NickMolliconi\lib\site-packages\pycaret\internal\persistence.py:373, in load_model(model_name, platform, authentication, verbose)
#     371     if verbose:
#     372         print("Transformation Pipeline and Model Successfully Loaded")
# --> 373     return joblib.load(model_name)
#     375 # cloud providers
#     376 elif platform == "aws":
#
# File C:\Users\NickMolliconi\lib\site-packages\joblib\numpy_pickle.py:579, in load(filename, mmap_mode)
#     577         obj = _unpickle(fobj)
#     578 else:
# --> 579     with open(filename, 'rb') as f:
#     580         with _read_fileobject(f, filename, mmap_mode) as fobj:
#     581             if isinstance(fobj, str):
#     582                 # if the returned file object is a string, this means we
#     583                 # try to load a pickle file generated with an version of
#     584                 # Joblib so we load it with joblib compatibility function.
#
# FileNotFoundError: [Errno 2] No such file or directory: 'ada.pkl'

# %%
from IPython.display import Code

Code('predict_diabetes.py')
# Out:
# import pandas as pd
# from pycaret.classification import predict_model, load_model
#
# def load_data(filepath):
#     """
#     Loads diabetes data into a DataFrame from a string filepath.
#     """
#     df = pd.read_csv(filepath, index_col='Patient number')
#     return df
#
#
# def make_predictions(df):
#     """
#     Uses the pycaret best model to make predictions on data in the df dataframe.
#     """
#     model = load_model('LDA')
#     predictions = predict_model(model, data=df)
#     predictions.rename({'Label': 'Diabetes_prediction'}, axis=1, inplace=True)
#     predictions['Diabetes_prediction'].replace({1: 'Diabetes', 0: 'No diabetes'},
#                                             inplace=True)
#     return predictions['Diabetes_prediction']
#
#
# if __name__ == "__main__":
#     df = load_data('data/new_diabetes_data.csv')
#     predictions = make_predictions(df)
#     print('predictions:')
#     print(predictions)

# %%
# %run predict_diabetes.py
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~\predict_diabetes.py:25, in <module>
#      21     return predictions['Diabetes_prediction']
#      24 if __name__ == "__main__":
# ---> 25     df = load_data('data/new_diabetes_data.csv')
#      26     predictions = make_predictions(df)
#      27     print('predictions:')
#
# File ~\predict_diabetes.py:8, in load_data(filepath)
#       4 def load_data(filepath):
#       5     """
#       6     Loads diabetes data into a DataFrame from a string filepath.
#       7     """
# ----> 8     df = pd.read_csv(filepath, index_col='Patient number')
#       9     return df
#
# File C:\Users\NickMolliconi\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File C:\Users\NickMolliconi\lib\site-packages\pandas\io\parsers\readers.py:680, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     665 kwds_defaults = _refine_defaults_read(
#     666     dialect,
#     667     delimiter,
#    (...)
#     676     defaults={"delimiter": ","},
#     677 )
#     678 kwds.update(kwds_defaults)
# --> 680 return _read(filepath_or_buffer, kwds)
#
# File C:\Users\NickMolliconi\lib\site-packages\pandas\io\parsers\readers.py:575, in _read(filepath_or_buffer, kwds)
#     572 _validate_names(kwds.get("names", None))
#     574 # Create the parser.
# --> 575 parser = TextFileReader(filepath_or_buffer, **kwds)
#     577 if chunksize or iterator:
#     578     return parser
#
# File C:\Users\NickMolliconi\lib\site-packages\pandas\io\parsers\readers.py:933, in TextFileReader.__init__(self, f, engine, **kwds)
#     930     self.options["has_index_names"] = kwds["has_index_names"]
#     932 self.handles: IOHandles | None = None
# --> 933 self._engine = self._make_engine(f, self.engine)
#
# File C:\Users\NickMolliconi\lib\site-packages\pandas\io\parsers\readers.py:1217, in TextFileReader._make_engine(self, f, engine)
#    1213     mode = "rb"
#    1214 # error: No overload variant of "get_handle" matches argument types
#    1215 # "Union[str, PathLike[str], ReadCsvBuffer[bytes], ReadCsvBuffer[str]]"
#    1216 # , "str", "bool", "Any", "Any", "Any", "Any", "Any"
# -> 1217 self.handles = get_handle(  # type: ignore[call-overload]
#    1218     f,
#    1219     mode,
#    1220     encoding=self.options.get("encoding", None),
#    1221     compression=self.options.get("compression", None),
#    1222     memory_map=self.options.get("memory_map", False),
#    1223     is_text=is_text,
#    1224     errors=self.options.get("encoding_errors", "strict"),
#    1225     storage_options=self.options.get("storage_options", None),
#    1226 )
#    1227 assert self.handles is not None
#    1228 f = self.handles.handle
#
# File C:\Users\NickMolliconi\lib\site-packages\pandas\io\common.py:789, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     784 elif isinstance(handle, str):
#     785     # Check whether the filename is to be opened in binary mode.
#     786     # Binary mode does not support 'encoding' and 'newline'.
#     787     if ioargs.encoding and "b" not in ioargs.mode:
#     788         # Encoding
# --> 789         handle = open(
#     790             handle,
#     791             ioargs.mode,
#     792             encoding=ioargs.encoding,
#     793             errors=errors,
#     794             newline="",
#     795         )
#     796     else:
#     797         # Binary mode
#     798         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/new_diabetes_data.csv'

# %% [markdown]
# Summary - Issues this week with the code as I continued to get errors once I established which model was the best, which in the churn data, it was the ada model.  No issues with creating the GetHub or using VSCode.

# %% [markdown]
# # Summary

# %% [markdown]
# Write a short summary of the process and results here.
